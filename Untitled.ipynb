# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.mpl_style', 'default')
# %matplotlib inline
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
from bokeh.models import GMapPlot
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86c5154a-2e62-480a-86eb-f07c04e4eff6">Loading BokehJS ...</span>
#     </div>

# %%
# %pwd
# Out:
# '/Users/thulasyammal/Desktop/EDS4'

# %%
data=pd.read_csv("ALL.csv")

# %%
data.head()
# Out:
#                                   Site_Location              StateID  \
# 0  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 1  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 2  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 3  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 4  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
#
#        Date  Time So2_Conc No2_Conc O3_Conc Co_Conc PM10_Conc
# 0  20090101   100   N/A      N/A     N/A     N/A       N/A
# 1  20090101   200   N/A      N/A     N/A     N/A       N/A
# 2  20090101   300   N/A      N/A     N/A     N/A       N/A
# 3  20090101   400   N/A      N/A     N/A     N/A       N/A
# 4  20090101   500   N/A      N/A     N/A     N/A       N/A

# %%
data.tail()
# Out:
#                                             Site_Location  \
# 253411  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253412  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253413  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253414  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253415  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
#
#                     StateID      Date  Time  So2_Conc  No2_Conc   O3_Conc  \
# 253411  WILAYAH PERSEKUTUAN  20151231  2000     0.002  CAL          0.006
# 253412  WILAYAH PERSEKUTUAN  20151231  2100     0.001     0.026  CAL
# 253413  WILAYAH PERSEKUTUAN  20151231  2200  CAL          0.024     0.003
# 253414  WILAYAH PERSEKUTUAN  20151231  2300     0.001     0.021     0.003
# 253415  WILAYAH PERSEKUTUAN  20151231  2400     0.002     0.023     0.002
#
#        Co_Conc PM10_Conc
# 253411    0.92        27
# 253412       1        29
# 253413    1.17        24
# 253414     1.1        25
# 253415    1.26        29

# %%
data['Time'] = data['Time'].apply(lambda i: ('{:d}'.format(i).zfill(4)))
data.head()
# Out:
#                                   Site_Location              StateID  \
# 0  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 1  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 2  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 3  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 4  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
#
#        Date  Time So2_Conc No2_Conc O3_Conc Co_Conc PM10_Conc
# 0  20090101  0100   N/A      N/A     N/A     N/A       N/A
# 1  20090101  0200   N/A      N/A     N/A     N/A       N/A
# 2  20090101  0300   N/A      N/A     N/A     N/A       N/A
# 3  20090101  0400   N/A      N/A     N/A     N/A       N/A
# 4  20090101  0500   N/A      N/A     N/A     N/A       N/A

# %%
data.tail()
# Out:
#                                             Site_Location  \
# 253411  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253412  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253413  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253414  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253415  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
#
#                     StateID      Date  Time  So2_Conc  No2_Conc   O3_Conc  \
# 253411  WILAYAH PERSEKUTUAN  20151231  2000     0.002  CAL          0.006
# 253412  WILAYAH PERSEKUTUAN  20151231  2100     0.001     0.026  CAL
# 253413  WILAYAH PERSEKUTUAN  20151231  2200  CAL          0.024     0.003
# 253414  WILAYAH PERSEKUTUAN  20151231  2300     0.001     0.021     0.003
# 253415  WILAYAH PERSEKUTUAN  20151231  2400     0.002     0.023     0.002
#
#        Co_Conc PM10_Conc
# 253411    0.92        27
# 253412       1        29
# 253413    1.17        24
# 253414     1.1        25
# 253415    1.26        29

# %%
data['time'] = data[['Date','Time']].apply(lambda x : '{}{}'.format(x[0],x[1]), axis=1)

# %%
data.head()
# Out:
#                                   Site_Location              StateID  \
# 0  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 1  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 2  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 3  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
# 4  Sek. Keb. Batu Muda, Batu Muda, Kuala Lumpur  WILAYAH PERSEKUTUAN
#
#        Date  Time So2_Conc No2_Conc O3_Conc Co_Conc PM10_Conc          time
# 0  20090101  0100   N/A      N/A     N/A     N/A       N/A     200901010100
# 1  20090101  0200   N/A      N/A     N/A     N/A       N/A     200901010200
# 2  20090101  0300   N/A      N/A     N/A     N/A       N/A     200901010300
# 3  20090101  0400   N/A      N/A     N/A     N/A       N/A     200901010400
# 4  20090101  0500   N/A      N/A     N/A     N/A       N/A     200901010500

# %%
data.tail()
# Out:
#                                             Site_Location  \
# 253411  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253412  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253413  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253414  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253415  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
#
#                     StateID      Date  Time  So2_Conc  No2_Conc   O3_Conc  \
# 253411  WILAYAH PERSEKUTUAN  20151231  2000     0.002  CAL          0.006
# 253412  WILAYAH PERSEKUTUAN  20151231  2100     0.001     0.026  CAL
# 253413  WILAYAH PERSEKUTUAN  20151231  2200  CAL          0.024     0.003
# 253414  WILAYAH PERSEKUTUAN  20151231  2300     0.001     0.021     0.003
# 253415  WILAYAH PERSEKUTUAN  20151231  2400     0.002     0.023     0.002
#
#        Co_Conc PM10_Conc          time
# 253411    0.92        27  201512312000
# 253412       1        29  201512312100
# 253413    1.17        24  201512312200
# ...

# %%
data.dtypes
# Out:
# Site_Location    object
# StateID          object
# Date              int64
# Time             object
# So2_Conc         object
# No2_Conc         object
# O3_Conc          object
# Co_Conc          object
# PM10_Conc        object
# time             object
# dtype: object

# %%
import pandas as pd
import datetime as dt

def my_to_datetime(date_str):
    if date_str[8:10] != '24':
        return pd.to_datetime(date_str, format='%Y%m%d%H%M')

    date_str = date_str[0:8] + '00' + date_str[10:]
    return pd.to_datetime(date_str, format='%Y%m%d%H%M') + \
           dt.timedelta(days=1)

print(my_to_datetime('201704102400'))
# Out:
# 2017-04-11 00:00:00

# %%
print(my_to_datetime('201704102400'))
# Out:
# 2017-04-11 00:00:00

# %%
data['timem'] = data['time'].apply(lambda i:my_to_datetime(i) )

# %%
data.tail()
# Out:
#                                             Site_Location  \
# 253411  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253412  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253413  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253414  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
# 253415  Sek.Men.Keb.Seri Permaisuri, Cheras           ...
#
#                     StateID      Date  Time  So2_Conc  No2_Conc   O3_Conc  \
# 253411  WILAYAH PERSEKUTUAN  20151231  2000     0.002  CAL          0.006
# 253412  WILAYAH PERSEKUTUAN  20151231  2100     0.001     0.026  CAL
# 253413  WILAYAH PERSEKUTUAN  20151231  2200  CAL          0.024     0.003
# 253414  WILAYAH PERSEKUTUAN  20151231  2300     0.001     0.021     0.003
# 253415  WILAYAH PERSEKUTUAN  20151231  2400     0.002     0.023     0.002
#
#        Co_Conc PM10_Conc          time               timem
# 253411    0.92        27  201512312000 2015-12-31 20:00:00
# ...

# %%
data.dtypes
# Out:
# Site_Location            object
# StateID                  object
# Date                      int64
# Time                     object
# So2_Conc                 object
# No2_Conc                 object
# O3_Conc                  object
# Co_Conc                  object
# PM10_Conc                object
# time                     object
# timem            datetime64[ns]
# dtype: object

# %%
data.shape
# Out:
# (253416, 11)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df=data

# %%
#3 different stations
BM=df.loc[df['Site_Location'].str.contains('Batu Muda')]
CH=df.loc[df['Site_Location'].str.contains('Cheras')]
PU=df.loc[df['Site_Location'].str.contains('Putrajaya')]

# %%
PU.head()
# Out:
#                                            Site_Location              StateID  \
# 61344  Sek. Keb. Putrajaya 8(2), Jln P8/E2, Presint 8...  WILAYAH PERSEKUTUAN
# 61345  Sek. Keb. Putrajaya 8(2), Jln P8/E2, Presint 8...  WILAYAH PERSEKUTUAN
# 61346  Sek. Keb. Putrajaya 8(2), Jln P8/E2, Presint 8...  WILAYAH PERSEKUTUAN
# 61347  Sek. Keb. Putrajaya 8(2), Jln P8/E2, Presint 8...  WILAYAH PERSEKUTUAN
# 61348  Sek. Keb. Putrajaya 8(2), Jln P8/E2, Presint 8...  WILAYAH PERSEKUTUAN
#
#            Date  Time  So2_Conc  No2_Conc   O3_Conc   Co_Conc PM10_Conc  \
# 61344  20050101  0100  N/A       N/A       N/A       N/A             22
# 61345  20050101  0200  N/A       N/A       N/A       N/A             28
# 61346  20050101  0300  N/A       N/A       N/A       N/A             14
# 61347  20050101  0400  N/A       N/A       N/A       N/A             12
# 61348  20050101  0500  N/A       N/A       N/A       N/A             21
#
#                time               timem
# ...

# %%
#Take only 5 columns
BMS=BM.loc[:,['timem','So2_Conc','No2_Conc','O3_Conc','Co_Conc',"PM10_Conc"]]
CHS=CH.loc[:,['timem','So2_Conc','No2_Conc','O3_Conc','Co_Conc',"PM10_Conc"]]
PUS=PU.loc[:,['timem','So2_Conc','No2_Conc','O3_Conc','Co_Conc',"PM10_Conc"]]

# %%
BMS.head()
BMS.dtypes
# Out:
# timem        datetime64[ns]
# So2_Conc             object
# No2_Conc             object
# O3_Conc              object
# Co_Conc              object
# PM10_Conc            object
# dtype: object

# %%
#Change object to numeric
BMS.So2_Conc = pd.to_numeric(BMS.So2_Conc,errors = "coerce")
BMS.No2_Conc = pd.to_numeric(BMS.No2_Conc,errors = "coerce")
BMS.O3_Conc = pd.to_numeric(BMS.O3_Conc,errors = "coerce")
BMS.Co_Conc = pd.to_numeric(BMS.Co_Conc,errors = "coerce")
BMS.PM10_Conc = pd.to_numeric(BMS.PM10_Conc,errors = "coerce")

# %%
BMS.dtypes
# Out:
# timem        datetime64[ns]
# So2_Conc            float64
# No2_Conc            float64
# O3_Conc             float64
# Co_Conc             float64
# PM10_Conc           float64
# dtype: object

# %%
#Change object to numeric
CHS.So2_Conc = pd.to_numeric(CHS.So2_Conc,errors = "coerce")
CHS.No2_Conc = pd.to_numeric(CHS.No2_Conc,errors = "coerce")
CHS.O3_Conc = pd.to_numeric(CHS.O3_Conc,errors = "coerce")
CHS.Co_Conc = pd.to_numeric(CHS.Co_Conc,errors = "coerce")
CHS.PM10_Conc = pd.to_numeric(CHS.PM10_Conc,errors = "coerce")

# %%
CHS.dtypes
# Out:
# timem        datetime64[ns]
# So2_Conc            float64
# No2_Conc            float64
# O3_Conc             float64
# Co_Conc             float64
# PM10_Conc           float64
# dtype: object

# %%
#Change object to numeric
PUS.So2_Conc = pd.to_numeric(PUS.So2_Conc,errors = "coerce")
PUS.No2_Conc = pd.to_numeric(PUS.No2_Conc,errors = "coerce")
PUS.O3_Conc = pd.to_numeric(PUS.O3_Conc,errors = "coerce")
PUS.Co_Conc = pd.to_numeric(PUS.Co_Conc,errors = "coerce")
PUS.PM10_Conc = pd.to_numeric(PUS.PM10_Conc,errors = "coerce")

# %%
#Change timem as index
BMS = BMS.set_index('timem')
CHS = CHS.set_index('timem')
PUS = PUS.set_index('timem')

# %%
PUS.dtypes
# Out:
# So2_Conc     float64
# No2_Conc     float64
# O3_Conc      float64
# Co_Conc      float64
# PM10_Conc    float64
# dtype: object

# %%
BMS.dtypes
# Out:
# So2_Conc     float64
# No2_Conc     float64
# O3_Conc      float64
# Co_Conc      float64
# PM10_Conc    float64
# dtype: object

# %%
BMS.head()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc
# timem
# 2009-01-01 01:00:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 02:00:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 03:00:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 04:00:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 05:00:00       NaN       NaN      NaN      NaN        NaN

# %%
BMS.tail()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc
# timem
# 2015-12-31 20:00:00     0.002     0.024      NaN     0.45       33.0
# 2015-12-31 21:00:00     0.002     0.026    0.003     0.54       31.0
# 2015-12-31 22:00:00     0.002     0.017    0.002     0.63       30.0
# 2015-12-31 23:00:00     0.002     0.019    0.002     0.72       30.0
# 2016-01-01 00:00:00     0.002     0.020    0.002     0.81       29.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Hourly data", fontsize=16)


axes[0,0].set(title='SO2')
axes[0,0].plot(BMS['So2_Conc'])
axes[0,0].plot(CHS['So2_Conc'])
axes[0,0].plot(PUS['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMS['No2_Conc'])
axes[0,1].plot(CHS['No2_Conc'])
axes[0,1].plot(PUS['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMS['O3_Conc'])
axes[1,0].plot(CHS['O3_Conc'])
axes[1,0].plot(PUS['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMS['Co_Conc'])
axes[1,1].plot(CHS['Co_Conc'])
axes[1,1].plot(PUS['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMS['PM10_Conc'])
axes[2,0].plot(CHS['PM10_Conc'])
axes[2,0].plot(PUS['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSD = pd.DataFrame()
CHSD = pd.DataFrame()
PUSD = pd.DataFrame()
BMSD = BMS.resample('D').mean()
CHSD = CHS.resample('D').mean()
PUSD = PUS.resample('D').mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Daily data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSD['So2_Conc'])
axes[0,0].plot(CHSD['So2_Conc'])
axes[0,0].plot(PUSD['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSD['No2_Conc'])
axes[0,1].plot(CHSD['No2_Conc'])
axes[0,1].plot(PUSD['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSD['O3_Conc'])
axes[1,0].plot(CHSD['O3_Conc'])
axes[1,0].plot(PUSD['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSD['Co_Conc'])
axes[1,1].plot(CHSD['Co_Conc'])
axes[1,1].plot(PUSD['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSD['PM10_Conc'])
axes[2,0].plot(CHSD['PM10_Conc'])
axes[2,0].plot(PUSD['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSW = pd.DataFrame()
CHSW = pd.DataFrame()
PUSW = pd.DataFrame()
BMSW = BMS.resample('W').mean()
CHSW = CHS.resample('W').mean()
PUSW = PUS.resample('W').mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("weekly Data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSW['So2_Conc'])
axes[0,0].plot(CHSW['So2_Conc'])
axes[0,0].plot(PUSW['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSW['No2_Conc'])
axes[0,1].plot(CHSW['No2_Conc'])
axes[0,1].plot(PUSW['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSW['O3_Conc'])
axes[1,0].plot(CHSW['O3_Conc'])
axes[1,0].plot(PUSW['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSW['Co_Conc'])
axes[1,1].plot(CHSW['Co_Conc'])
axes[1,1].plot(PUSW['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSW['PM10_Conc'])
axes[2,0].plot(CHSW['PM10_Conc'])
axes[2,0].plot(PUSW['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSM = pd.DataFrame()
CHSM = pd.DataFrame()
PUSM = pd.DataFrame()
BMSM = BMS.resample('M').mean()
CHSM = CHS.resample('M').mean()
PUSM = PUS.resample('M').mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Monthly data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSM['So2_Conc'])
axes[0,0].plot(CHSM['So2_Conc'])
axes[0,0].plot(PUSM['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSM['No2_Conc'])
axes[0,1].plot(CHSM['No2_Conc'])
axes[0,1].plot(PUSM['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSM['O3_Conc'])
axes[1,0].plot(CHSM['O3_Conc'])
axes[1,0].plot(PUSM['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSM['Co_Conc'])
axes[1,1].plot(CHSM['Co_Conc'])
axes[1,1].plot(PUSM['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSM['PM10_Conc'])
axes[2,0].plot(CHSM['PM10_Conc'])
axes[2,0].plot(PUSM['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSY=BMS.groupby(BMS.index.year).mean()
CHSY=CHS.groupby(CHS.index.year).mean()
PUSY=PUS.groupby(PUS.index.year).mean()
PUSY.head()
# Out:
#        So2_Conc  No2_Conc   O3_Conc   Co_Conc  PM10_Conc
# timem
# 2005   0.002493  0.011212  0.025444  0.794203  50.384094
# 2006   0.001625  0.011754  0.026452  0.503909  49.571107
# 2007   0.002276  0.013956  0.021049  0.527962  38.990736
# 2008   0.002327  0.013272  0.020655  0.565662  39.533527
# 2009   0.001957  0.013008  0.019848  0.586881  40.972945

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Yearly data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSY['So2_Conc'])
axes[0,0].plot(CHSY['So2_Conc'])
axes[0,0].plot(PUSY['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSY['No2_Conc'])
axes[0,1].plot(CHSY['No2_Conc'])
axes[0,1].plot(PUSY['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSY['O3_Conc'])
axes[1,0].plot(CHSY['O3_Conc'])
axes[1,0].plot(PUSY['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSY['Co_Conc'])
axes[1,1].plot(CHSY['Co_Conc'])
axes[1,1].plot(PUSY['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSY['PM10_Conc'])
axes[2,0].plot(CHSY['PM10_Conc'])
axes[2,0].plot(PUSY['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
GDP=pd.read_csv("GDP.csv")

# %%
GDP.head()
# Out:
#    Year   GDPPC
# 0  2005  42,414
# 1  2006  45,519
# 2  2007  49,687
# 3  2008  56,135
# 4  2009  57,040

# %%
GDP.dtypes
# Out:
# Year      int64
# GDPPC    object
# dtype: object

# %%
GDP.head()
# Out:
#    Year   GDPPC
# 0  2005  42,414
# 1  2006  45,519
# 2  2007  49,687
# 3  2008  56,135
# 4  2009  57,040

# %%
GDP.Year=GDP['Year'].apply(str)

# %%
GDP.head()
# Out:
#    Year   GDPPC
# 0  2005  42,414
# 1  2006  45,519
# 2  2007  49,687
# 3  2008  56,135
# 4  2009  57,040

# %%
GDP.dtypes
# Out:
# Year     object
# GDPPC    object
# dtype: object

# %%
import pandas as pd


def my_to_datetime(date_str):
    

    date_str = date_str[0:4] 
    return pd.to_datetime(date_str, format='%Y') 
           

print(my_to_datetime('2017'))
# Out:
# 2017-01-01 00:00:00

# %%
GDP['Year'] = GDP['Year'].apply(lambda i:my_to_datetime(i) )

# %%
GDP.head()
# Out:
#         Year   GDPPC
# 0 2005-01-01  42,414
# 1 2006-01-01  45,519
# 2 2007-01-01  49,687
# 3 2008-01-01  56,135
# 4 2009-01-01  57,040

# %%
#GDP = GDP.set_index('Year')

# %%
#Change object to numeric
GDP.GDPPC = pd.to_numeric(GDP.GDPPC,errors = "coerce")

# %%
GDP.head()
# Out:
#         Year  GDPPC
# 0 2005-01-01    NaN
# 1 2006-01-01    NaN
# 2 2007-01-01    NaN
# 3 2008-01-01    NaN
# 4 2009-01-01    NaN

# %%
GDP.dtypes
# Out:
# GDPPC    object
# dtype: object

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Yearly data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSY['So2_Conc'])
axes[0,0].plot(CHSY['So2_Conc'])
axes[0,0].plot(PUSY['So2_Conc'])

axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSY['No2_Conc'])
axes[0,1].plot(CHSY['No2_Conc'])
axes[0,1].plot(PUSY['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSY['O3_Conc'])
axes[1,0].plot(CHSY['O3_Conc'])
axes[1,0].plot(PUSY['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSY['Co_Conc'])
axes[1,1].plot(CHSY['Co_Conc'])
axes[1,1].plot(PUSY['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSY['PM10_Conc'])
axes[2,0].plot(CHSY['PM10_Conc'])
axes[2,0].plot(PUSY['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
plot(GDP['GDPPC'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-279ccb7c74ef> in <module>()
# ----> 1 plot(GDP['GDPPC'])
#
# NameError: name 'plot' is not defined

# %%
GDP.head()
# Out:
#            GDP Per capita
# Year
# 2005-01-01         42,414
# 2006-01-01         45,519
# 2007-01-01         49,687
# 2008-01-01         56,135
# 2009-01-01         57,040

# %%
GDP.GDP Per capita = pd.to_numeric(GDP.GDP Per capita,errors = "coerce")
# Out:
#   File "<ipython-input-84-7b74163da5e3>", line 1
#     GDP.GDP Per capita = pd.to_numeric(GDP.GDP Per capita,errors = "coerce")
#               ^
# SyntaxError: invalid syntax

# %%
#GDP['Year'] = GDP['Year'].apply(lambda i:my_to_datetime(i) )

# %%
GDP.head()
# Out:
#                                                 Year GDP Per capita
# 0  0    2005\n1    2006\n2    2007\n3    2008\n4 ...         42,414
# 1  0    2005\n1    2006\n2    2007\n3    2008\n4 ...         45,519
# 2  0    2005\n1    2006\n2    2007\n3    2008\n4 ...         49,687
# 3  0    2005\n1    2006\n2    2007\n3    2008\n4 ...         56,135
# 4  0    2005\n1    2006\n2    2007\n3    2008\n4 ...         57,040

# %%
GDP['Year'] = datetime(GDP['Year'],'%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-383-6a1158d8b62b> in <module>()
# ----> 1 GDP['Year'] = datetime(GDP['Year'],'%Y')
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Yearly data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSY['So2_Conc'])
axes[0,0].plot(CHSY['So2_Conc'])
axes[0,0].plot(PUSY['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSY['No2_Conc'])
axes[0,1].plot(CHSY['No2_Conc'])
axes[0,1].plot(PUSY['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSY['O3_Conc'])
axes[1,0].plot(CHSY['O3_Conc'])
axes[1,0].plot(PUSY['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSY['Co_Conc'])
axes[1,1].plot(CHSY['Co_Conc'])
axes[1,1].plot(PUSY['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSY['PM10_Conc'])
axes[2,0].plot(CHSY['PM10_Conc'])
axes[2,0].plot(PUSY['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSH=BMS.groupby(BMS.index.hour).mean()
CHSH=CHS.groupby(CHS.index.hour).mean()
PUSH=PUS.groupby(PUS.index.hour).mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("24 hours data", fontsize=16)

axes[0,0].set(title='SO2')
axes[0,0].plot(BMSH['So2_Conc'])
axes[0,0].plot(CHSH['So2_Conc'])
axes[0,0].plot(PUSH['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSH['No2_Conc'])
axes[0,1].plot(CHSH['No2_Conc'])
axes[0,1].plot(PUSH['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSH['O3_Conc'])
axes[1,0].plot(CHSH['O3_Conc'])
axes[1,0].plot(PUSH['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSH['Co_Conc'])
axes[1,1].plot(CHSH['Co_Conc'])
axes[1,1].plot(PUSH['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSH['PM10_Conc'])
axes[2,0].plot(CHSH['PM10_Conc'])
axes[2,0].plot(PUSH['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSW=BMS.groupby(BMS.index.weekday).mean()
CHSW=CHS.groupby(CHS.index.weekday).mean()
PUSW=PUS.groupby(PUS.index.weekday).mean()

# %%
#BMSW = BMS.groupby(BMS.index.dayofweek).mean()
#CHSW = CHS.groupby(CHS.index.dayofweek).mean()
#PUSW = PUS.groupby(PUS.index.dayofweek).mean()
#BMSW.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
#CHSW.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
#PUSW.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Weekday of the data", fontsize=16)


axes[0,0].set(title='SO2')
axes[0,0].plot(BMSW['So2_Conc'])
axes[0,0].plot(CHSW['So2_Conc'])
axes[0,0].plot(PUSW['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSW['No2_Conc'])
axes[0,1].plot(CHSW['No2_Conc'])
axes[0,1].plot(PUSW['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSW['O3_Conc'])
axes[1,0].plot(CHSW['O3_Conc'])
axes[1,0].plot(PUSW['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSW['Co_Conc'])
axes[1,1].plot(CHSW['Co_Conc'])
axes[1,1].plot(PUSW['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSW['PM10_Conc'])
axes[2,0].plot(CHSW['PM10_Conc'])
axes[2,0].plot(PUSW['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSM=BMS.groupby(BMS.index.month).mean()
CHSM=CHS.groupby(CHS.index.month).mean()
PUSM=PUS.groupby(PUS.index.month).mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,15))
fig.suptitle("Monthly data", fontsize=16)


axes[0,0].set(title='SO2')
axes[0,0].plot(BMSM['So2_Conc'])
axes[0,0].plot(CHSM['So2_Conc'])
axes[0,0].plot(PUSM['So2_Conc'])
axes[0,0].legend(['BM', 'CH', 'PU'])
axes[0,1].plot(BMSM['No2_Conc'])
axes[0,1].plot(CHSM['No2_Conc'])
axes[0,1].plot(PUSM['No2_Conc'])
axes[0,1].legend(['BM', 'CH', 'PU'])
axes[0,1].set(title='NO2')
axes[1,0].plot(BMSM['O3_Conc'])
axes[1,0].plot(CHSM['O3_Conc'])
axes[1,0].plot(PUSM['O3_Conc'])
axes[1,0].legend(['BM', 'CH', 'PU'])
axes[1,0].set(title='O3')
axes[1,1].plot(BMSM['Co_Conc'])
axes[1,1].plot(CHSM['Co_Conc'])
axes[1,1].plot(PUSM['Co_Conc'])
axes[1,1].legend(['BM', 'CH', 'PU'])
axes[1,1].set(title='CO')
axes[2,0].plot(BMSM['PM10_Conc'])
axes[2,0].plot(CHSM['PM10_Conc'])
axes[2,0].plot(PUSM['PM10_Conc'])
axes[2,0].legend(['BM', 'CH', 'PU'])
axes[2,0].set(title='PM10');

# %%
BMSM = BMS.resample('M').mean()

# %%
BMSM.head()
# Out:
#             So2_Conc  No2_Conc   O3_Conc   Co_Conc  PM10_Conc
# timem
# 2009-01-31  0.002126  0.014540  0.018125  0.713271  35.593614
# 2009-02-28  0.002237  0.018042  0.019020  0.846964  44.501488
# 2009-03-31  0.001883  0.018886  0.015812  0.849194  36.551075
# 2009-04-30  0.002271  0.016614  0.017978  0.837750  37.262500
# 2009-05-31  0.002116  0.016873  0.020475  0.748133  41.177419

# %%
ts=BMSM['So2_Conc']
ts.head()
# Out:
# timem
# 2009-01-31    0.002126
# 2009-02-28    0.002237
# 2009-03-31    0.001883
# 2009-04-30    0.002271
# 2009-05-31    0.002116
# Freq: M, Name: So2_Conc, dtype: float64

# %%
plt.plot(ts)

# %%
from matplotlib import pyplot
from pandas.tools.plotting import autocorrelation_plot

# %%
autocorrelation_plot(ts)
pyplot.show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 

# fit model
model = ARIMA(ts, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:             D.So2_Conc   No. Observations:                   84
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                 507.331
# Method:                       css-mle   S.D. of innovations              0.001
# Date:                Sat, 17 Mar 2018   AIC                          -1000.663
# Time:                        00:26:30   BIC                           -983.647
# Sample:                    02-28-2009   HQIC                          -993.823
#                          - 01-31-2016
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             5.646e-06   2.74e-05      0.206      0.837   -4.81e-05    5.94e-05
# ar.L1.D.So2_Conc    -0.2748      0.104     -2.632      0.010      -0.479      -0.070
# ...

# %%
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 

X = ts.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=0.002838, expected=0.002372
# predicted=0.002230, expected=0.002571
# predicted=0.002757, expected=0.002719
# predicted=0.002520, expected=0.001849
# /Applications/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# predicted=0.002362, expected=0.001281
# /Applications/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# predicted=0.001648, expected=0.002667
# predicted=0.002373, expected=0.003121
# /Applications/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# predicted=0.002509, expected=0.003054
# ...

# %%
BMST=BMS
CHST=CHS
PUST=PUS

# %%
BMST['Site'] = 'BM'
BMST.tail()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc Site
# timem
# 2015-12-31 20:00:00     0.002     0.024      NaN     0.45       33.0   BM
# 2015-12-31 21:00:00     0.002     0.026    0.003     0.54       31.0   BM
# 2015-12-31 22:00:00     0.002     0.017    0.002     0.63       30.0   BM
# 2015-12-31 23:00:00     0.002     0.019    0.002     0.72       30.0   BM
# 2016-01-01 00:00:00     0.002     0.020    0.002     0.81       29.0   BM

# %%
CHST['Site'] = 'CH'
CHST.tail()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc Site
# timem
# 2015-12-31 20:00:00     0.002       NaN    0.006     0.92       27.0   CH
# 2015-12-31 21:00:00     0.001     0.026      NaN     1.00       29.0   CH
# 2015-12-31 22:00:00       NaN     0.024    0.003     1.17       24.0   CH
# 2015-12-31 23:00:00     0.001     0.021    0.003     1.10       25.0   CH
# 2016-01-01 00:00:00     0.002     0.023    0.002     1.26       29.0   CH

# %%
PUST['Site'] = 'PU'
PUST.tail()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc Site
# timem
# 2015-12-31 20:00:00     0.002     0.036    0.007      NaN       53.0   PU
# 2015-12-31 21:00:00     0.002     0.026    0.012     0.99       52.0   PU
# 2015-12-31 22:00:00     0.002       NaN    0.004     1.51       58.0   PU
# 2015-12-31 23:00:00     0.002     0.033    0.002     1.35       51.0   PU
# 2016-01-01 00:00:00       NaN     0.028    0.001     1.32       40.0   PU

# %%
#KAD=BMST.merge(CHST,on='name').merge(PUST,on='name')
frames = [BMST, CHST, PUST]

result = pd.concat(frames)
df=result
df.dtypes
# Out:
# So2_Conc     float64
# No2_Conc     float64
# O3_Conc      float64
# Co_Conc      float64
# PM10_Conc    float64
# Site          object
# dtype: object

# %%
result.head()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc Site
# timem
# 2009-01-01 01:00:00       NaN       NaN      NaN      NaN        NaN   BM
# 2009-01-01 02:00:00       NaN       NaN      NaN      NaN        NaN   BM
# 2009-01-01 03:00:00       NaN       NaN      NaN      NaN        NaN   BM
# 2009-01-01 04:00:00       NaN       NaN      NaN      NaN        NaN   BM
# 2009-01-01 05:00:00       NaN       NaN      NaN      NaN        NaN   BM

# %%
df.to_csv('example.csv')

# %%
result.tail()
df=result
df.Site.unique()
# Out:
# array(['BM', 'CH', 'PU'], dtype=object)

# %%
import numpy as np
from numpy.random import randn
from numpy import pi
import pandas as pd

# %%
import bokeh.plotting as plt
from bokeh.models.formatters import DatetimeTickFormatter
from bokeh.models import FixedTicker, HoverTool
plt.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7bec9bf2-9dd1-4a89-a0eb-482277337357">Loading BokehJS ...</span>
#     </div>

# %%
# Create a dummy timeseries
ndays = 14
dates = pd.date_range('01-Jan-2016', periods=48*ndays, freq='30T')
temp = np.cos(np.linspace(0, 2*pi*ndays, 48*ndays) + pi/2)
noise = np.cumsum(0.2*randn(temp.size))
temp = pd.Series(20 + 5*temp + noise, index=dates)

# %%
import pandas_datareader as pdr
import pandas as pd
from pandas_datareader import data
import datetime
import numpy as np
from bokeh.plotting import figure, show
from bokeh.palettes import Spectral6
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6272c2d3-0ee5-4792-ae2a-eb458b062984">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral5
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.transform import factor_cmap

output_file("groupby.html")

df.Site = df.Site.astype(str)
group = df.groupby('Site')

source = ColumnDataSource(df)

Site_cmap =factor_cmap('Site', palette=Spectral5, factors=['one', 'two', 'three'])

p = figure(plot_height=350, x_range=group, title="So2_Conc",
           toolbar_location=None, tools="")

p.line(x='Site', top='So2_Conc', width=1, source=source)

p.y_range.start = 0
p.xgrid.grid_line_color = None
p.xaxis.axis_label = "some stuff"
p.xaxis.major_label_orientation = 1.2
p.outline_line_color = None

show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-d3bf6b68cd39> in <module>()
#      18            toolbar_location=None, tools="")
#      19
# ---> 20 p.line(x='Site', top='So2_Conc', width=1, source=source)
#      21
#      22 p.y_range.start = 0
#
# TypeError: line() missing 1 required positional argument: 'y'

# %%
#from bokeh.io import export_png

#p = figure(plot_width=800, plot_height=250, x_axis_type="datetime")
#p.line(df['timem'], df['So2_Conc'], color='navy', alpha=0.5)

#export_png(p, filename="plot.png")

# %%
df.head()
df.dtypes
# Out:
# So2_Conc     float64
# No2_Conc     float64
# O3_Conc      float64
# Co_Conc      float64
# PM10_Conc    float64
# Site          object
# dtype: object

# %%
#Daily = df.reset_index().groupby(['Site','timem']).mean()
#dfm = Daily.set_index('timem').resample('D')['So2_Conc'].mean()

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9843bd67-1e5f-49f6-ac36-3872295f289d">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
from math import pi
from datetime import datetime as dt
from bokeh.io import output_file
#from bokeh.charts import show
from bokeh.models import DatetimeTickFormatter
from bokeh.plotting import figure
from bokeh.io import output_file

# %%
p = figure(plot_width=800, plot_height=250,x_axis_type='datetime')
p.line(BMST.index, BMST['So2_Conc'], color='navy', alpha=0.5)
p.line(CHST.index, CHST['So2_Conc'], color='red', alpha=0.5)
p.line(PUST.index, PUST['So2_Conc'], color='green', alpha=0.5)

show(p)   # save(p) will save without opening a new browser tab
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d9ebbc9d-4dc4-4bab-a2d2-538c9586aa61"></div>
# </div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
#monthly_summary_BM = BMST.resample('M').mean()
#monthly_summary_CH = CHST.resample('M').mean()
#monthly_summary_PU = PUST.resample('M').mean()

# %%
from bokeh.io import export_png

# %%
#from bokeh.layouts import column
#from bokeh.io import export_png

#output_file("muru1.html")

# create a new plot
#p1 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly SO2 levels at three KualaLumpur city stations')
#p1.line(monthly_summary_BM.index, monthly_summary_BM['So2_Conc'],legend="BM", color='navy', alpha=0.5)
#p1.line(monthly_summary_CH.index, monthly_summary_CH['So2_Conc'],legend="CH", color='red', alpha=0.5)
#p1.line(monthly_summary_PU.index, monthly_summary_PU['So2_Conc'],legend="PU", color='green', alpha=0.5)

# create a new plot
#p2 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly NO2 levels at three KualaLumpur city stations')
#p2.line(monthly_summary_BM.index, monthly_summary_BM['No2_Conc'],legend="BM", color='navy', alpha=0.5)
#p2.line(monthly_summary_CH.index, monthly_summary_CH['No2_Conc'],legend="CH", color='red', alpha=0.5)
#p2.line(monthly_summary_PU.index, monthly_summary_PU['No2_Conc'],legend="PU", color='green', alpha=0.5)

# create a new plot
#p3 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly O3 levels at three KualaLumpur city stations')
#p3.line(monthly_summary_BM.index, monthly_summary_BM['O3_Conc'],legend="BM", color='navy', alpha=0.5)
#p3.line(monthly_summary_CH.index, monthly_summary_CH['O3_Conc'],legend="CH", color='red', alpha=0.5)
#p3.line(monthly_summary_PU.index, monthly_summary_PU['O3_Conc'],legend="PU", color='green', alpha=0.5)

# create a new plot
#p4 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly CO levels at three KualaLumpur city stations')
#p4.line(monthly_summary_BM.index, monthly_summary_BM['Co_Conc'],legend="BM", color='navy', alpha=0.5)
#p4.line(monthly_summary_CH.index, monthly_summary_CH['Co_Conc'],legend="CH", color='red', alpha=0.5)
#p4.line(monthly_summary_PU.index, monthly_summary_PU['Co_Conc'],legend="PU", color='green', alpha=0.5)

# create a new plot
#p5 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly PM10 levels at three KualaLumpur city stations')
#p5.line(monthly_summary_BM.index, monthly_summary_BM['PM10_Conc'],legend="BM", color='navy', alpha=0.5)
#p5.line(monthly_summary_CH.index, monthly_summary_CH['PM10_Conc'],legend="CH", color='red', alpha=0.5)
#p5.line(monthly_summary_PU.index, monthly_summary_PU['PM10_Conc'],legend="PU", color='green', alpha=0.5)

#plot=column(p1, p2,p3,p4,p5)

#export_png(plot, filename="plot.png")

#export_png(plot, filename="plot.png")

#output_file(plot.png)
#show(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-80528755f8fa> in <module>()
#       2 from bokeh.io import export_png
#       3
# ----> 4 output_file("muru1.html")
#       5
#       6 # create a new plot
#
# NameError: name 'output_file' is not defined

# %%
BMST=BMS
CHST=CHS
PUST=PUS

# %%
#24 HOUR VALUE
#BMSTT = BMST.groupby(BMST.index.time).mean()
#CHSTT = CHST.groupby(CHST.index.time).mean()
#PUSTT = PUST.groupby(PUST.index.time).mean()
#BMSTT.head()

# %%
#BMSTT['Value'] = ['0000',0100', '0200', '0300','0400, 'yes']

# %%
BMST=BMS
CHST=CHS
PUST=PUS

# %%
BMSTW = BMST.groupby(BMST.index.dayofweek).mean()
CHSTW = CHST.groupby(CHST.index.dayofweek).mean()
PUSTW = PUST.groupby(PUST.index.dayofweek).mean()
BMSTW.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64', name='timem')

# %%
BMSTW['Value'] = ['Mon', 'Tue', 'Wed','Thu', 'Fri','Sat','Sun']

# %%
BMSTW
# Out:
#        So2_Conc  No2_Conc   O3_Conc   Co_Conc  PM10_Conc Value
# timem
# 0      0.002142  0.017253  0.018944  0.772894  45.924358   Mon
# 1      0.002311  0.018048  0.019145  0.804285  49.833525   Tue
# 2      0.002355  0.017839  0.019315  0.796140  49.873012   Wed
# 3      0.002336  0.017797  0.019091  0.787854  48.335164   Thu
# 4      0.002435  0.017985  0.019083  0.793221  48.445724   Fri
# 5      0.002397  0.016968  0.019685  0.745483  48.266705   Sat
# 6      0.002189  0.014568  0.020012  0.685215  47.530596   Sun

# %%
BMSTW.dtypes
# Out:
# So2_Conc     float64
# No2_Conc     float64
# O3_Conc      float64
# Co_Conc      float64
# PM10_Conc    float64
# Value         object
# dtype: object

# %%
BMSTW["Value"] = BMSTW["Value"].astype('category')
BMSTW.dtypes
# Out:
# So2_Conc      float64
# No2_Conc      float64
# O3_Conc       float64
# Co_Conc       float64
# PM10_Conc     float64
# Value        category
# dtype: object

# %%
a=(BMSTW['Value'])
a
# Out:
# timem
# 0    Mon
# 1    Tue
# 2    Wed
# 3    Thu
# 4    Fri
# 5    Sat
# 6    Sun
# Name: Value, dtype: category
# Categories (7, object): [Fri, Mon, Sat, Sun, Thu, Tue, Wed]

# %%
dfList = BMSTW['Value'].tolist()

# %%
# create a new plot
p1 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Hourly SO2 levels at three KualaLumpur city stations')
p1.line(BMSTW.index.get_weekday(), BMSTW['So2_Conc'],legend="BM", color='navy', alpha=0.5)
#p1.line(CHSTT.index, CHSTT['So2_Conc'],legend="CH", color='red', alpha=0.5)
#p1.line(PUSTT.index, PUSTT['So2_Conc'],legend="PU", color='green', alpha=0.5)

show(p1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-93bbe551aaf2> in <module>()
#       1 # create a new plot
#       2 p1 = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Hourly SO2 levels at three KualaLumpur city stations')
# ----> 3 p1.line(BMSTW.get_weekday(), BMSTW['So2_Conc'],legend="BM", color='navy', alpha=0.5)
#       4 #p1.line(CHSTT.index, CHSTT['So2_Conc'],legend="CH", color='red', alpha=0.5)
#       5 #p1.line(PUSTT.index, PUSTT['So2_Conc'],legend="PU", color='green', alpha=0.5)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'get_weekday'

# %%
by_weekday = BMST.So2_Conc.groupby(BMST.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);

# %%
by_month = BMST.So2_Conc.groupby(BMST.index.month).mean()
by_month
# Out:
# timem
# 1     0.001913
# 2     0.002227
# 3     0.002325
# 4     0.002349
# 5     0.002242
# 6     0.002734
# 7     0.002542
# 8     0.002207
# 9     0.002348
# 10    0.002553
# 11    0.002323
# 12    0.001948
# Name: So2_Conc, dtype: float64

# %%
by_month = BMST.So2_Conc.groupby(BMST.index.month).mean()
by_month.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug','Sep','Oct','Nov','Dec']
by_month.plot(style=[':', '--', '-']);

# %%
#Resample weekly=W,daily=d,monthly=M
monthly_summary_BMSO2 = pd.DataFrame()
monthly_summary_CHSO2 = pd.DataFrame()
monthly_summary_PUSO2 = pd.DataFrame()
monthly_summary_BMSO2['SO2'] = BMST.So2_Conc.resample('M').mean()
monthly_summary_CHSO2['SO2'] = CHST.So2_Conc.resample('M').mean()
monthly_summary_PUSO2['SO2'] = PUST.So2_Conc.resample('M').mean()

# %%
monthly_summary_BMSO2.head()
# Out:
#                  SO2
# timem
# 2009-01-31  0.002126
# 2009-02-28  0.002237
# 2009-03-31  0.001883
# 2009-04-30  0.002271
# 2009-05-31  0.002116

# %%
p = figure(plot_width=800, plot_height=250,x_axis_type='datetime',title='Monthly mean Hourly SO2 levels at three KualaLumpur city stations')
p.line(monthly_summary_BMSO2.index, monthly_summary_BMSO2['SO2'],legend="BM", color='navy', alpha=0.5)
p.line(monthly_summary_CHSO2.index, monthly_summary_CHSO2['SO2'],legend="CH", color='red', alpha=0.5)
p.line(monthly_summary_PUSO2.index, monthly_summary_PUSO2['SO2'],legend="PU", color='green', alpha=0.5)

show(p)   # save(p) will save without opening a new browser tab
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e661d0f8-b2f7-451f-8427-d889e50139f9"></div>
# </div>

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(daily_summary_BMSO2NO2.index, daily_summary_BMSO2NO2['SO2'], 'g-')
ax2.plot(daily_summary_BMSO2NO2.index, daily_summary_BMSO2NO2['NO2'], 'b-')

ax1.set_xlabel('Date')
ax1.set_ylabel('SO2', color='g')
ax2.set_ylabel('NO2', color='b')

plt.show()
plt.rcParams['figure.figsize'] = 12,5

# %%
upsampled=BMS.resample('1Min')

# %%
interpolated = upsampled.interpolate(method='linear')
len(interpolated)
# Out:
# 3680581

# %%
interpolated.head()
# Out:
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc
# timem
# 2009-01-01 01:00:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 01:01:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 01:02:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 01:03:00       NaN       NaN      NaN      NaN        NaN
# 2009-01-01 01:04:00       NaN       NaN      NaN      NaN        NaN

# %%
a=BMS.resample('1Min', base=30)

# %%
len(a)
# Out:
# 3680581

# %%
a.tail()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .resample() is now a deferred operation
# You called tail(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
#   """Entry point for launching an IPython kernel.
#                      So2_Conc  No2_Conc  O3_Conc  Co_Conc  PM10_Conc
# timem
# 2015-12-31 23:56:00       NaN       NaN      NaN      NaN        NaN
# 2015-12-31 23:57:00       NaN       NaN      NaN      NaN        NaN
# 2015-12-31 23:58:00       NaN       NaN      NaN      NaN        NaN
# 2015-12-31 23:59:00       NaN       NaN      NaN      NaN        NaN
# 2016-01-01 00:00:00     0.002      0.02    0.002     0.81       29.0
